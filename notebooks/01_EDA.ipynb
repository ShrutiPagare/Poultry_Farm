# %%
{
 "nbformat": 4,
 "nbformat_minor": 5,
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.10.0"}
 },
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# 🐔 Poultry AI — Exploratory Data Analysis\n", "Notebook 01 | Author: Poultry AI Team"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import sys; sys.path.insert(0, '..')\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import plotly.express as px\n",
    "from configs.config import RAW_CSV\n",
    "\n",
    "sns.set_theme(style='whitegrid', palette='muted')\n",
    "pd.set_option('display.float_format', '{:,.2f}'.format)\n",
    "\n",
    "df = pd.read_csv(RAW_CSV)\n",
    "print(f'Shape: {df.shape}')\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.describe().T.style.background_gradient(cmap='Blues')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Missing values\n",
    "miss = df.isnull().sum()\n",
    "print('Missing values:', miss[miss > 0] if miss.any() else 'None 🎉')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Profit distribution\n",
    "fig, axes = plt.subplots(1, 2, figsize=(14, 5))\n",
    "sns.histplot(df['estimated_profit'], bins=50, kde=True, ax=axes[0], color='#2563EB')\n",
    "axes[0].set_title('Profit Distribution')\n",
    "sns.boxplot(data=df, x='risk_label', y='estimated_profit',\n",
    "            palette={'Low':'#22c55e','Medium':'#f59e0b','High':'#ef4444'}, ax=axes[1])\n",
    "axes[1].set_title('Profit by Risk Label')\n",
    "plt.tight_layout(); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Correlation heatmap\n",
    "num_cols = ['chick_count','feed_consumed_kg','mortality_rate','feed_efficiency',\n",
    "            'estimated_profit','farm_score','profit_per_bird','revenue_per_bird']\n",
    "plt.figure(figsize=(10, 8))\n",
    "sns.heatmap(df[num_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0)\n",
    "plt.title('Feature Correlation Matrix', fontsize=14)\n",
    "plt.tight_layout(); plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# State-wise profitability\n",
    "fig = px.bar(df.groupby('state')['estimated_profit'].mean().sort_values(ascending=False).reset_index(),\n",
    "             x='state', y='estimated_profit', title='Average Profit by State',\n",
    "             color='estimated_profit', color_continuous_scale='Blues')\n",
    "fig.show()"
   ]
  }
 ]
}
